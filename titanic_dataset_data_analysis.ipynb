# %% [markdown]
# <a href="https://colab.research.google.com/github/Mikhthad/Titanic-data-set-data-analysis/blob/main/titanic_dataset_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/Titanic-Dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 1) Get the details of passengers who survived and were younger than 18 years old.
df[(df['Age']<18) & (df['Survived']==1)]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 9             10         1       2       Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 22            23         1       3               McGowan, Miss. Anna "Annie"
# 39            40         1       3               Nicola-Yarred, Miss. Jamila
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# ..           ...       ...     ...                                       ...
# 830          831         1       3   Yasbeck, Mrs. Antoni (Selini Alexander)
# 831          832         1       2           Richards, Master. George Sibley
# 853          854         1       1                 Lines, Miss. Mary Conover
# 869          870         1       3           Johnson, Master. Harold Theodor
# 875          876         1       3          Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
# 2) Get the details of male passengers who were older than 40 years old.
df[(df['Sex']=="male") & (df['Age']>=40)]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 30            31         0       1        Uruchurtu, Don. Manuel E  male
# 33            34         0       2           Wheadon, Mr. Edward H  male
# 35            36         0       1  Holverson, Mr. Alexander Oskar  male
# 54            55         0       1  Ostby, Mr. Engelhart Cornelius  male
# ..           ...       ...     ...                             ...   ...
# 845          846         0       3             Abbing, Mr. Anthony  male
# 851          852         0       3             Svensson, Mr. Johan  male
# 857          858         1       1          Daly, Mr. Peter Denis   male
# 860          861         0       3         Hansen, Mr. Claus Peter  male
# 873          874         0       3     Vander Cruyssen, Mr. Victor  male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# ...

# %%
# 3) Get the details of passengers who paid a fare greater than $30 and survived.
df[(df['Fare']>30) & (df['Survived']==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 9             10         1       2
# 23            24         1       1
# 25            26         1       3
# ..           ...       ...     ...
# 849          850         1       1
# 853          854         1       1
# 856          857         1       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 4) Get the details of female passengers who did not survive
df[(df['Sex']=="female") & (df['Survived']==0)]
# Out:
#      PassengerId  Survived  Pclass  \
# 14            15         0       3
# 18            19         0       3
# 24            25         0       3
# 38            39         0       3
# 40            41         0       3
# ..           ...       ...     ...
# 854          855         0       2
# 863          864         0       3
# 882          883         0       3
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 38                  Vander Planke, Miss. Augusta Maria  female  18.0      2
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 5) Get the details of passengers who were in either the first or second class.
df[(df['Pclass']==1) | (df['Pclass']==2)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 9             10         1       2
# 11            12         1       1
# ..           ...       ...     ...
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 6) Get the details of passengers who had more than two siblings/spouses aboard the Titanic and did not survive.
df[(df['SibSp']>=2) & (df['Survived']==0)]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 16            17         0       3                     Rice, Master. Eugene
# 24            25         0       3            Palsson, Miss. Torborg Danira
# 27            28         0       1           Fortune, Mr. Charles Alexander
# 38            39         0       3       Vander Planke, Miss. Augusta Maria
# 48            49         0       3                      Samaan, Mr. Youssef
# 50            51         0       3               Panula, Master. Juha Niilo
# 59            60         0       3       Goodwin, Master. William Frederick
# 63            64         0       3                    Skoog, Master. Harald
# 69            70         0       3                        Kink, Mr. Vincenz
# 71            72         0       3               Goodwin, Miss. Lillian Amy
# ...

# %%
# 7) Get the details of passengers who were in the third class and were older than 30 years old.
df[(df['Pclass']>=3) & (df['Age']>=30)]
# Out:
#      PassengerId  Survived  Pclass  \
# 4              5         0       3
# 13            14         0       3
# 18            19         0       3
# 25            26         1       3
# 40            41         0       3
# ..           ...       ...     ...
# 860          861         0       3
# 873          874         0       3
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 4                             Allen, Mr. William Henry    male  35.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 8) Get the details of passengers who were younger than 15 years old and had parents/children aboard.
df[(df['Age']<15) & (df['Parch']>=1)]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 16            17         0       3                      Rice, Master. Eugene
# 24            25         0       3             Palsson, Miss. Torborg Danira
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# ..           ...       ...     ...                                       ...
# 827          828         1       2                     Mallet, Master. Andre
# 831          832         1       2           Richards, Master. George Sibley
# 850          851         0       3   Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                   Boulos, Miss. Nourelain
# 869          870         1       3           Johnson, Master. Harold Theodor
#
# ...

# %%
# 9) Get the details of male passengers who paid less than $10 for their fare.
df[(df['Sex']=='male') & (df['Fare']<10)]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 12            13         0       3  Saundercock, Mr. William Henry  male
# 26            27         0       3         Emir, Mr. Farred Chehab  male
# ..           ...       ...     ...                             ...   ...
# 877          878         0       3            Petroff, Mr. Nedelio  male
# 878          879         0       3              Laleff, Mr. Kristo  male
# 881          882         0       3              Markun, Mr. Johann  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch           Ticket    Fare Cabin Embarked
# ...

# %%
# 10) Get the details of passengers who were in the third class, younger than 20, and had siblings/spouses aboard.
df[(df['Pclass']==3) & (df['Age']<20) & (df['SibSp']>1)]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 16            17         0       3                     Rice, Master. Eugene
# 24            25         0       3            Palsson, Miss. Torborg Danira
# 38            39         0       3       Vander Planke, Miss. Augusta Maria
# 50            51         0       3               Panula, Master. Juha Niilo
# 59            60         0       3       Goodwin, Master. William Frederick
# 63            64         0       3                    Skoog, Master. Harald
# 68            69         1       3          Andersson, Miss. Erna Alexandra
# 71            72         0       3               Goodwin, Miss. Lillian Amy
# 119          120         0       3        Andersson, Miss. Ellis Anna Maria
# 147          148         0       3         Ford, Miss. Robina Maggie "Ruby"
# ...

# %%
# 11) Get the details of passengers who were either younger than 10 years or older than 60 years, and survived.
df[(df['Age']<10) | (df['Age']>60) & (df['Survived']==1)]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 7              8         0       3             Palsson, Master. Gosta Leonard
# 10            11         1       3            Sandstrom, Miss. Marguerite Rut
# 16            17         0       3                       Rice, Master. Eugene
# 24            25         0       3              Palsson, Miss. Torborg Danira
# 43            44         1       2   Laroche, Miss. Simonne Marie Anne Andree
# ..           ...       ...     ...                                        ...
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
# 831          832         1       2            Richards, Master. George Sibley
# 850          851         0       3    Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                    Boulos, Miss. Nourelain
# 869          870         1       3            Johnson, Master. Harold Theodor
#
# ...

# %%
# 12) Get the name,passenge Id and Cabin number who were in the 2nd class and ticket fare grater than 50
second_class_passenger= df[['Name','PassengerId','Cabin']][(df['Fare']>50) & (df['Pclass']==2)]

# %%
second_class_passenger
# Out:
#                                  Name  PassengerId Cabin
# 72               Hood, Mr. Ambrose Jr           73   NaN
# 120       Hickman, Mr. Stanley George          121   NaN
# 385         Davies, Mr. Charles Henry          386   NaN
# 615               Herman, Miss. Alice          616   NaN
# 655         Hickman, Mr. Leonard Mark          656   NaN
# 665                Hickman, Mr. Lewis          666   NaN
# 754  Herman, Mrs. Samuel (Jane Laver)          755   NaN

# %%
# 13) get the name,passenger and ticket Number who were female and embarked Southampton
female_at_Southampton=df[['Name','PassengerId','Ticket']][(df['Sex']=='female') & (df['Embarked']=='S')]

# %%
female_at_Southampton
# Out:
#                                                   Name  PassengerId  \
# 2                               Heikkinen, Miss. Laina            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)            9
# 10                     Sandstrom, Miss. Marguerite Rut           11
# 11                            Bonnell, Miss. Elizabeth           12
# ..                                                 ...          ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)          872
# 880       Shelley, Mrs. William (Imanita Parrish Hall)          881
# 882                       Dahlberg, Miss. Gerda Ulrika          883
# 887                       Graham, Miss. Margaret Edith          888
# 888           Johnston, Miss. Catherine Helen "Carrie"          889
#
#                Ticket
# 2    STON/O2. 3101282
# 3              113803
# 8              347742
# 10            PP 9549
# 11             113783
# ...

# %%
# 14) get the name of male  passengers who were survived
Survived_males=df['Name'][(df['Sex']=='male') & (df['Survived']==1)]

# %%
Survived_males
# Out:
# 17        Williams, Mr. Charles Eugene
# 21               Beesley, Mr. Lawrence
# 23        Sloper, Mr. William Thompson
# 36                    Mamee, Mr. Hanna
# 55                   Woolner, Mr. Hugh
#                     ...
# 838                    Chip, Mr. Chang
# 839               Marechal, Mr. Pierre
# 857             Daly, Mr. Peter Denis
# 869    Johnson, Master. Harold Theodor
# 889              Behr, Mr. Karl Howell
# Name: Name, Length: 109, dtype: object

# %%
# 15) get details of passengers who were embarked in cherbourg
Embarked_in_Cherbourg = df[df['Embarked']=='C']

# %%
Embarked_in_Cherbourg
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 9             10         1       2
# 19            20         1       3
# 26            27         0       3
# 30            31         0       1
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 26                             Emir, Mr. Farred Chehab    male   NaN      0
# 30                            Uruchurtu, Don. Manuel E    male  40.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 16) get the details of passengers in between 3 to 10 years old
df[(df['Age']>=3) & (df['Age']<=10)]
# Out:
#      PassengerId  Survived  Pclass  \
# 10            11         1       3
# 24            25         0       3
# 43            44         1       2
# 50            51         0       3
# 58            59         1       2
# 63            64         0       3
# 147          148         0       3
# 165          166         1       3
# 171          172         0       3
# 182          183         0       3
# 184          185         1       3
# 193          194         1       2
# 233          234         1       3
# 237          238         1       2
# 261          262         1       3
# 278          279         0       3
# 348          349         1       3
# 374          375         0       3
# 407          408         1       2
# 419          420         0       3
# 445          446         1       1
# 448          449         1       3
# 480          481         0       3
# 489          490         1       3
# 535          536         1       2
# ...

# %%
# 18) get the passenger id,name and class who where embarked in queenstown and survived.
df[['PassengerId','Name','Pclass']][(df['Embarked']=='Q') & (df['Survived']==1)]
# Out:
#      PassengerId                                             Name  Pclass
# 22            23                      McGowan, Miss. Anna "Annie"       3
# 28            29                    O'Dwyer, Miss. Ellen "Nellie"       3
# 32            33                         Glynn, Miss. Mary Agatha       3
# 44            45                    Devaney, Miss. Margaret Delia       3
# 47            48                        O'Driscoll, Miss. Bridget       3
# 82            83                   McDermott, Miss. Brigdet Delia       3
# 109          110                              Moran, Miss. Bertha       3
# 156          157                 Gilnagh, Miss. Katherine "Katie"       3
# 186          187  O'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)       3
# 198          199                 Madigan, Miss. Margaret "Maggie"       3
# 208          209                        Carr, Miss. Helen "Ellen"       3
# 241          242                   Murphy, Miss. Katherine "Kate"       3
# ...

# %%
# 19) get the details of passengers who have siblings and spouses abroad is more than 2 or parents and children abroad is less than 2.
df[(df['SibSp']>2) & (df['Parch']<2)]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 16            17         0       3
# 24            25         0       3
# 50            51         0       3
# 85            86         1       3
# 164          165         0       3
# 171          172         0       3
# 176          177         0       3
# 229          230         0       3
# 266          267         0       3
# 278          279         0       3
# 374          375         0       3
# 409          410         0       3
# 485          486         0       3
# 686          687         0       3
# 726          727         1       2
# 787          788         0       3
# 824          825         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 16                                Rice, Master. Eugene    male   2.0      4
# ...

# %%
# 20) get the details of male passengers who were embarked in southampton.
df[(df['Sex']=='male') & (df['Embarked']=='S')]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# 12            13         0       3  Saundercock, Mr. William Henry  male
# ..           ...       ...     ...                             ...   ...
# 878          879         0       3              Laleff, Mr. Kristo  male
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# 21) get the name, age, ticket, cabin no and fare of female passengers who were embarked in queenstown.
df[['Name','Age','Ticket','Cabin','Fare']][(df['Sex']=='female') & (df['Embarked']=='Q')]
# Out:
#                                                 Name   Age  Ticket Cabin  \
# 22                       McGowan, Miss. Anna "Annie"  15.0  330923   NaN
# 28                     O'Dwyer, Miss. Ellen "Nellie"   NaN  330959   NaN
# 32                          Glynn, Miss. Mary Agatha   NaN  335677   NaN
# 44                     Devaney, Miss. Margaret Delia  19.0  330958   NaN
# 47                         O'Driscoll, Miss. Bridget   NaN   14311   NaN
# 82                    McDermott, Miss. Brigdet Delia   NaN  330932   NaN
# 109                              Moran, Miss. Bertha   NaN  371110   NaN
# 156                 Gilnagh, Miss. Katherine "Katie"  16.0   35851   NaN
# 186  O'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)   NaN  370365   NaN
# 198                 Madigan, Miss. Margaret "Maggie"   NaN  370370   NaN
# 208                        Carr, Miss. Helen "Ellen"  16.0  367231   NaN
# 241                   Murphy, Miss. Katherine "Kate"   NaN  367230   NaN
# ...

# %%
# 22) get the details of passengers in first class
df[df['Pclass']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 23) get the details of female passengers who have more than 3 siblings and spouses abroad.
df[(df['Sex']=='female') & (df['SibSp']>=3)]
# Out:
#      PassengerId  Survived  Pclass  \
# 24            25         0       3
# 68            69         1       3
# 71            72         0       3
# 85            86         1       3
# 88            89         1       1
# 119          120         0       3
# 180          181         0       3
# 229          230         0       3
# 233          234         1       3
# 341          342         1       1
# 374          375         0       3
# 409          410         0       3
# 485          486         0       3
# 541          542         0       3
# 542          543         0       3
# 634          635         0       3
# 642          643         0       3
# 726          727         1       2
# 792          793         0       3
# 813          814         0       3
# 863          864         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# ...

# %%
# 24) get the male passenger details who either younger than 18 and older than 60.
df[(df['Sex']=='male') & (df['Age']<18) | (df['Age']>60)]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 16            17         0       3                     Rice, Master. Eugene
# 33            34         0       2                    Wheadon, Mr. Edward H
# 50            51         0       3               Panula, Master. Juha Niilo
# 54            55         0       1           Ostby, Mr. Engelhart Cornelius
# ..           ...       ...     ...                                      ...
# 841          842         0       2                 Mudd, Mr. Thomas Charles
# 844          845         0       3                      Culumovic, Mr. Jeso
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 851          852         0       3                      Svensson, Mr. Johan
# 869          870         1       3          Johnson, Master. Harold Theodor
#
# ...

# %%
# 25) get the details of passengers who were in second class, older than 50 and parents/children abroad.
df[(df['Pclass']==2) & (df['Age']>50) & (df['Parch'])]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 684          685         0       2      Brown, Mr. Thomas William Solomon
# 774          775         1       2  Hocking, Mrs. Elizabeth (Eliza Needs)
#
#         Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 684    male  60.0      1      1  29750  39.0   NaN        S
# 774  female  54.0      1      3  29105  23.0   NaN        S
